# %% [markdown]
# # GETTING STARTED with PRINTING

# %%
print("Leonel Messi")
# Out:
# Leonel Messi

# %%
print(7)
print(11.259)
print(6,7,9)
print (False)
print('Bear', 'Tiger', 'Horse','Eagle')
print('Tiger' , 18.95, True )
# Out:
# 7
# 11.259
# 6 7 9
# False
# Bear Tiger Horse Eagle
# Tiger 18.95 True

# %% [markdown]
# # DATA TYPES

# %% [markdown]
# ### 1. INTEGER

# %%
#Integer

print(108)
print(26739300278)
# Out:
# 108
# 26739300278

# %% [markdown]
# ### 2. FLOAT

# %%
#float

print(13.5)
print(2637383.1788262)
# Out:
# 13.5
# 2637383.1788262

# %% [markdown]
# ### 3. BOOLEAN

# %%
#boolean

print(True)
print(False)
# Out:
# True
# False

# %% [markdown]
# ### 4. COMPLEX

# %%
#complex 

print(2+3j)
# Out:
# (2+3j)

# %% [markdown]
# ### 5. STRINGS

# %%
#Strings

print("Vamos Espanha")
print("Come On You Gunners")
print("Visca Barca , Visca Cataluna ") 
print("Vamos Argentina")
# Out:
# Vamos Espanha
# Come On You Gunners
# Visca Barca , Visca Cataluna
# Vamos Argentina

# %% [markdown]
# ### 6. LIST

# %%
#List

print([1 , 5 , 8 , 11, 19])

print(['Tiger' , 'Lion', 'Bear'])
# Out:
# [1, 5, 8, 11, 19]
# ['Tiger', 'Lion', 'Bear']

# %% [markdown]
# ### 7. TUPLE

# %%
#Tuple 

print((1 , 25 , 34 ))
print(( 'Tiger' , 'Lion', 'Bear'))
# Out:
# (1, 25, 34)
# ('Tiger', 'Lion', 'Bear')

# %% [markdown]
# ### 8. SETS

# %%
#Sets

print({ 12, 32, 76})
print({ 'Tiger' , 'Lion', 'Bear'})
# Out:
# {32, 12, 76}
# {'Tiger', 'Bear', 'Lion'}

# %% [markdown]
# ### 9. DICTIONARY

# %%
#Dictionary 

print({'Name' : 'Lionel Messi' , 'Age' : 39 , 'Height' : 170})
# Out:
# {'Name': 'Lionel Messi', 'Age': 39, 'Height': 170}

# %% [markdown]
# >
# >##
#  ## MUTABLE & IMMUTABLE Data Types:
# >> ### MUTABLE --> LIST , SET , DICTIONARY
# >> ### IMMUTABLE --> STRINGS , TUPLE , INT , FLOAT , BOOLEAN , COMPLEX etc
# >>
# >> ##

# %% [markdown]
# ## COMMENTS

# %%
#I am Writing This Comment For Reference 
# Python is Awesome

# %% [markdown]
# # VARIABLES

# %% [markdown]
# > ### Dynamic Typing --> PHP , Python
# > ### Static Typing --> C , C++ , Java
# > ### Dynamic Binding --> PHP , Python
# > ### Static Binding --> C , C++ , Java

# %%
name = 'Leo Messi' # String Type Value
age = 39 # INT Type Value
height = 1.69 # Float Type Value
favourite_quote = 'Visca Barca , Visca Cataluna' # String Type Value
G_O_A_T = True 

print(name)
print(age)
print(height)
print(favourite_quote)
print(G_O_A_T)
# Out:
# Leo Messi
# 39
# 1.69
# Visca Barca , Visca Cataluna
# True

# %% [markdown]
# ### Multiple Variable Declaration

# %%
# SYNTAX 1

name = 'Messi' ; age = 39 ; height = 1.69
print(name)
print(age)
print(height)
# Out:
# Messi
# 39
# 1.69

# %%
# SYNTAX 2

name , age , height = 'Messi' , 39 , 1.69
print(name)
print(age)
print(height)
# Out:
# Messi
# 39
# 1.69

# %%
# SYNTAX 3

Messi = Cruyff = Pele = Maradona = "G.O.A.T"
print ( Messi)
print(Cruyff)
print(Pele)
print(Maradona)
# Out:
# G.O.A.T
# G.O.A.T
# G.O.A.T
# G.O.A.T

# %% [markdown]
# # KEYWORDS
# ### Python is a Case Sensitive Programming Language
#
# * **PYTHON has 33 Keywords**

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ## IDENTIFIERS
#
# > ### A Python Identifier is a name used to identify a Variable , Class , Function , Module and Other Objects
#
# >  * **Can Start Only with an Alphabet or _**
# > * **Followed by 0 or More Letters , _ or Digits**
# > * **Keywords Can Not be Used as Identifier**

# %% [markdown]
# ## TAKING USER INPUT

# %%
#input()

# %%
first_num= input("Enter the First Number")
second_num = input ( "Enter the Second Number")

print(first_num)
print(second_num)
# Out:
# Enter the First Number 25
# Enter the Second Number 35
# 25
# 35

# %% [markdown]
# ## DATA TYPE CONVERSION

# %%
#Type

type(12)
# Out:
# int

# %%
type(23.5)
# Out:
# float

# %%
type(" Leo Messi")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type([ 1, 3, 5])
# Out:
# list

# %%
type((1, 3, 5))
# Out:
# tuple

# %%
type({ 1 ,3 ,5})
# Out:
# set

# %%
type ({ 'num' : 7 , 'num_type' : 'Prime_Number'})
# Out:
# dict

# %% [markdown]
# ## TYPE CONVERSION

# %% [markdown]
# ### IMPLICIT TYPE CONVERSION

# %%
23 + 35.5
# Out:
# 58.5

# %%
34 * (5 + 7j)
# Out:
# (170+238j)

# %% [markdown]
# ### EXPLICIT TYPE CONVERSION

# %%
# INT 
int( 24.567)
# Out:
# 24

# %%
# FLOAT
float( 599)
# Out:
# 599.0

# %%
#String

str(287)
# Out:
# '287'

# %%
# Boolean

bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
# Complex

complex (446)
# Out:
# (446+0j)

# %%
# LIST

list("LEONEL")
# Out:
# ['L', 'E', 'O', 'N', 'E', 'L']

# %%
# TUPLE

tuple("LEONEL")
# Out:
# ('L', 'E', 'O', 'N', 'E', 'L')

# %%
first_num = int(input(" Enter the Fisrt Number"))
second_num = int(input(" Enter the Second Number "))
print(f"\n\tThe Multiplied Value is : {first_num * second_num}" )
# Out:
#  Enter the Fisrt Number 20
#  Enter the Second Number  30
# 	The Multiplied Value is : 600

# %% [markdown]
# # LITERALS
# > ### In Python LITERALS are Raw Data Given or Assigned to a Variable. It can be of Many Types :
#
# > * **Numerical Literals**
#
# > * **String Literals**
#
# > * **Boolean Literals**
#
# > * **Special Literals**

# %% [markdown]
# #### 1. NUMERICAL LITERALS

# %%
num_1 = 0b101101 # BINARY LITERALS ( Start with 0b )

num_2 = 25604 # DECIMAL LITERALS

num_3 = 0o02354 # OCTAL LITERALS ( Start with 0o )

num_4 = 0x1092ac5 # HEXADECIMAL LITERALS 9 Start with 0x )

print(num_1)
print( num_2)
print(num_3)
print(num_4)
print()

# FLOAT LITERALS  

num_5 = 2.5 
num_6 = 2.5e5
num_7=2.5e-3

print(num_5)
print(num_6)
print(num_7)

# COMPLEX LITERALS

num_8 = 33 + 24j

print( num_8 , num_8.imag ,num_8.real)
# Out:
# 45
# 25604
# 1260
# 17377989
#
# 2.5
# 250000.0
# 0.0025
# (33+24j) 24.0 33.0

# %% [markdown]
# #### 2. STRING LITERALS

# %%
str_1 = " Leo Messi"
str_2 = ' Leo Messi'
char_1 = 'L'
unicode = u"\U0001F600" , "\U0001F602" , "\U0001F60E" #This Example of Emoji Unicodes
multiline_str = """ Leonel Messi is the Real G.O.A.T of Football . He won 8 Ballon Dor. He won World Cup , UCL , La Liga , Copa America Trophies"""
raw_str = r" I like the \n Football Match"

print(str_1)
print(str_2)
print(char_1)
print(unicode)
print(multiline_str)
print(raw_str)
# Out:
#  Leo Messi
#  Leo Messi
# L
# ('😀', '😂', '😎')
#  Leonel Messi is the Real G.O.A.T of Football . He won 8 Ballon Dor. He won World Cup , UCL , La Liga , Copa America Trophies
#  I like the \n Football Match

# %% [markdown]
# #### 3. BOOLEAN LITERALS

# %%
bool_1 = True + 55
bool_2 = False + 44
print(bool_1)
print(bool_2)
# Out:
# 56
# 44

# %% [markdown]
# #### 4. SPECIAL LITERALS

# %%
spec_lit = None 
print(spec_lit)
# Out:
# None

# %% [markdown]
# # OPERATORS
#
# > ### Operators are Used to Perform Operations of Variables and Values.
#
# > #### Types of Operators:
#
# > * **Arithmatic Operators**
# > * **Comparison Operators**
# > * **Logical Operators**
# > * **Bitwise Operators**
# > * **Assignment Operators**
# > * **Identity Operators**
# > * **Membership Operators**

# %% [markdown]
# #### 1. ARITHMATIC OPERATORS

# %%
x = 150
y = 12

print(x + y)
# Out:
# 162

# %%
print(x - y)
# Out:
# 138

# %%
print(x / y)
# Out:
# 12.5

# %%
print(x * y)
# Out:
# 1800

# %%
print(x % y) # Mod or Modulus ( Shows Remeinder)
# Out:
# 6

# %%
print(x ** y) # Power / Exponent
# Out:
# 129746337890625000000000000

# %%
print ( x // y) # Integer Division ( Gives Output in INTEGER )
# Out:
# 12

# %% [markdown]
# #### 2. COMPARISON OPERATORS

# %%
x > y
# Out:
# True

# %%
x < y
# Out:
# False

# %%
x == y
# Out:
# False

# %%
x <= y
# Out:
# False

# %%
x >= y
# Out:
# True

# %%
x != y
# Out:
# True

# %% [markdown]
# #### 3. LOGICAL OPERATORS

# %%
x = True
y = False

# %%
print(x or y)
# Out:
# True

# %%
print(x and y)
# Out:
# False

# %%
print(not y)
# Out:
# True

# %%
print(not x)
# Out:
# False

# %% [markdown]
# #### 4. BITWISE OPERATORS

# %%
x = 5

y = 3

# %%
print(x & y)
# Out:
# 1

# %%
print(x | y)
# Out:
# 7

# %%
print(x >> y)
# Out:
# 0

# %%
print(x << y)
# Out:
# 40

# %%
print(~x)
# Out:
# -6

# %% [markdown]
# #### ASSIGNMENT OPERATOR

# %%
a = 5 
print(a)
# Out:
# 5

# %%
a += 5 # a = a + 5
print(a)

a -= 5 # a = a - 5
print(a)

a *= 5 # a = a * 5
print(a)

a /= 5 # a = a / 5
print(a)
# Out:
# 10
# 5
# 25
# 5.0

# %%
a = 5

a &= 5
print(a)
# Out:
# 5

# %% [markdown]
# #### IDENTITY OPERATORS

# %%
a = 4 
b = 4 
print(a is b )
# Out:
# True

# %%
a = 'Leo'
b = 'Leo'
print(a is b )
# Out:
# True

# %%
a = [ 1 ,2 , 6 ]
b = [ 1 ,2 , 6 ]
print( a is b )
# Out:
# False

# %%
a = "Arsenal FC "
print('F' in a)
print('Ar' not in a)
# Out:
# True
# False

# %%
a = [ 1 , 8 , 33, 45 , 667 ]
print( 33 in a )
print( 100 in a )
# Out:
# True
# False

# %% [markdown]
# # IF-ELSE Conditional Statement

# %%
# LOG IN PAGE
# EXPECTED USER NAME : Shubhayu_97
# EXPECTED USER ID : XRX65285
# EXPECTED PASSWORD : &%RTG_#

user_name = input(" Enter Your User Name ")

user_id = input(" Enter Your User ID ")

password = input(" Enter Your Password ")

if user_name == "Shubhayu_97" and user_id == "XRX65285" and password == "&%RTG_#" :
    print("Welcome to the Portal")
else:
    print( "You Entered Wrong Log In Credentials")
# Out:
#  Enter Your User Name  Shubhayu_97
#  Enter Your User ID  XRX65285
#  Enter Your Password  &%RTG_#
# Welcome to the Portal

# %% [markdown]
# ### NESTED IF-ELSE CONDITION
# * ## **1**

# %%
# LOG IN PAGE
# EXPECTED USER NAME : Shubhayu_97
# EXPECTED USER ID : XRX65285
# EXPECTED PASSWORD : &%RTG_#

## If USER ID , USER NAME is CORRECT , But , Password is WRONG , 
##Then , Give Another Chance to Enter the Password with Warning " Wrong Password" and Ask for Input 

user_name = input(" Enter Your User Name ")

user_id = input(" Enter Your User ID ")

password = input(" Enter Your Password ")

if user_name == "Shubhayu_97" and user_id == "XRX65285" and password == "&%RTG_#" :
    print("Welcome to the Portal")
elif user_name == "Shubhayu_97" and user_id == "XRX65285" and password != "&%RTG_#" :
    print("Password is Incorrect")
    password = input(" Enter Correct Password ")
    if password == "&%RTG_#":
        print("Welcome to the Portal")
    else : 
        print("Still Incorrect Password, Try After Some Time")
else:
    print( "You Entered Wrong Log In Credentials")
# Out:
#  Enter Your User Name  Shubhayu_97
#  Enter Your User ID  XRX65285
#  Enter Your Password  yffIGi
# Password is Incorrect
#  Enter Correct Password  &%RTG_#
# Welcome to the Portal

# %% [markdown]
# * ## **2**

# %%
# LOG IN PAGE
# EXPECTED USER NAME : Shubhayu_97
# EXPECTED EMAIL ID : raja199@gmail.com
# EXPECTED USER ID : XRX65285
# EXPECTED PASSWORD : &%RTG_#

### If Email Does Not Contain @ in it , Then Fail it at once and Throw Error Message

## If USER ID , USER NAME is CORRECT , But , Password is WRONG , 
##Then , Give Another Chance to Enter the Password with Warning " Wrong Password" and Ask for Input 

user_name = input(" Enter Your User Name ")

email_id = input (" Enter Your Email ID ")

if '@' in email_id :
    
    password = input(" Enter Your Password ")
    user_id = input(" Enter Your User ID ")
    
    if user_name == "Shubhayu_97" and user_id == "XRX65285" and password == "&%RTG_#" :
        print("Welcome to the Portal")
    elif user_name == "Shubhayu_97" and user_id == "XRX65285" and password != "&%RTG_#" :
        print("Password is Incorrect")
        password = input(" Enter Correct Password ")
        if password == "&%RTG_#":
            print("Welcome to the Portal")
        else : 
            print("Still Incorrect Password, Try After Some Time")
    else:
        print( "You Entered Wrong Log In Credentials")
else:
    print(" Entered Wrong Email ID , Try Again ")
# Out:
#  Enter Your User Name  Shubhayu_97
#  Enter Your Email ID  raja199gmail.com
#  Entered Wrong Email ID , Try Again

# %% [markdown]
# # WHILE LOOP

# %%
val = int(input("Enter the Value : "))
i = 1 

while i <= 10 :
    new_val = (val * i )** 2
    i += 1
    print(new_val)
# Out:
# Enter the Value :  25
# 625
# 2500
# 5625
# 10000
# 15625
# 22500
# 30625
# 40000
# 50625
# 62500

# %%
val = int(input("Enter the Value : "))
i = 1 

while i <= 10 :
    new_val = (val * i )** 2
    i += 1
    print('(', val , '*' , i ,')', '^', 2 ,'=' ,new_val)
# Out:
# Enter the Value :  25
# ( 25 * 2 ) ^ 2 = 625
# ( 25 * 3 ) ^ 2 = 2500
# ( 25 * 4 ) ^ 2 = 5625
# ( 25 * 5 ) ^ 2 = 10000
# ( 25 * 6 ) ^ 2 = 15625
# ( 25 * 7 ) ^ 2 = 22500
# ( 25 * 8 ) ^ 2 = 30625
# ( 25 * 9 ) ^ 2 = 40000
# ( 25 * 10 ) ^ 2 = 50625
# ( 25 * 11 ) ^ 2 = 62500

# %% [markdown]
# # GENERATE RANDOM NUMBER and Play JACKPOT GAME

# %%
import random # This Lirary Generates Random Numbers within a Range

# %%
jackpot = random.randint(1,100) # Generate Random Number within the Range of 1 to 100 

guess = int(input("Guess a Number and Enter the Value : "))
counter = 1

while guess !=jackpot :
  
        
        
    if guess < jackpot:
        print("Guess Higher")
        guess = int(input("Guess a Number and Enter the Value : "))  
        counter += 1
    elif guess > jackpot :
        print("Guess Lower")
        guess = int(input("Guess a Number and Enter the Value : "))  
        counter += 1
print("\nCorrect Guess")

if counter <= 3 :
    print("You Won Jackpot")
else:
    print("\nHard Luck, Try Another Day")       
print("\nYou Took" , counter , " Guesses")
# Out:
# Guess a Number and Enter the Value :  35
# Guess Higher
# Guess a Number and Enter the Value :  45
# Guess Lower
# Guess a Number and Enter the Value :  40
# Guess Lower
# Guess a Number and Enter the Value :  38
# Guess Lower
# Guess a Number and Enter the Value :  37
# Guess Lower
# Guess a Number and Enter the Value :  36
# Correct Guess
#
# Hard Luck, Try Another Day
#
# You Took 6  Guesses

# %% [markdown]
# # FOR LOOP

# %% [markdown]
# ### Range Function

# %% [markdown]
# > * #### range ( initial value , upper range) ---> range( 1, 5 ) generates values from 1 to 4
# > * #### range ( upper range ) ---> range (5) generates values from 0 to 5 , If initial val not given , by default it takes 0 as initial value
# > * #### range ( initial value , upper value , increment ) ---> range( 1 , 10 , 2 ) generates values from 1 to 9 , but , with increment of 2

# %%
list(range(1,5))
# Out:
# [1, 2, 3, 4]

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
list(range(1 ,20 , 3))
# Out:
# [1, 4, 7, 10, 13, 16, 19]

# %% [markdown]
# ### SEQUENCE
# > #### SEQUENCES of Characters , Numbers , Words
# > #### List , Sets , Tuples are Examples of SEQUENCES

# %%
for i in range(1 , 30 , 3) : # Incremental Values
    print( "The Square of" , i , "is" , i**2)
# Out:
# The Square of 1 is 1
# The Square of 4 is 16
# The Square of 7 is 49
# The Square of 10 is 100
# The Square of 13 is 169
# The Square of 16 is 256
# The Square of 19 is 361
# The Square of 22 is 484
# The Square of 25 is 625
# The Square of 28 is 784

# %%
for i in range ( 40 , -20 , -4) :  # Decremental or Negative Incremental Values
    print (i)
# Out:
# 40
# 36
# 32
# 28
# 24
# 20
# 16
# 12
# 8
# 4
# 0
# -4
# -8
# -12
# -16

# %%
for i in 'Leonel Messi': # For Loop on String
    print(i)
# Out:
# L
# e
# o
# n
# e
# l
#
# M
# e
# s
# s
# i

# %%
for i in [ 1 , 3, 7, 11, 19]: # For Loop on List
    print(i)
# Out:
# 1
# 3
# 7
# 11
# 19

# %%
for i in ( 1 , 3, 7, 11, 19): # For Loop on Tuple
    print(i)
# Out:
# 1
# 3
# 7
# 11
# 19

# %%
for i in { 1 , 3, 7, 11, 19}: # For Loop on Set
    print(i)
# Out:
# 1
# 3
# 7
# 11
# 19

# %% [markdown]
# # NESTED LOOP Example

# %% [markdown]
# #### Print Pascal Triangle Pattern :

# %%
*
* *
* * *
* * * *
* * * * *
* * * * * *
* * * * * * *
* * * * * * * *
* * * * * * * * *

# %%
rows = int(input("Enter the Number of Rows : "))

for i in range ( 1 , rows + 1) :
    for j in range( 1, i):
        print("*" , end =" ")
    print("")
# Out:
# Enter the Number of Rows :  10
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * * * *
# * * * * * * * *
# * * * * * * * * *

# %% [markdown]
# ## BREAK , CONTINUE , PASS statements

# %% [markdown]
# ### BREAK Statement
#
# > * #### BREAK Statement Immediately Terminates the Current Loop where the Break Statement Condition is Met
# > * #### For Example ,
# >  ####   if i == 20 :
# >  ####     break;
# > * #### Once i = 20 , the Loop will Terminate and it will get out of the Loop

# %%
for i in range( 1 , 10 ):
    if i == 5 :
        break;
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# #### LINEAR SEARCHING EXAMPLE ( Using BREAK )

# %%
# LINEAR SEARCHING in a Big List
# Searching for 111 in the list
numbers = [
    3, 8, 12, 19, 24, 31, 37, 42, 48, 53,
    57, 61, 66, 72, 75, 81, 86, 90, 94, 99,
    102, 105, 108, 110, 111, 118, 124, 131, 139, 147,
    156, 163, 171, 184, 192, 205, 217, 229, 241, 256,
    268, 279, 291, 314, 336, 359, 387, 421, 456, 498
]
counter = 1 

for i in numbers :
    if i == 111 :
        break;
    counter += 1 
print( 111 , " is at the Position " , counter + 1 )
# Out:
# 111  is at the Position  26

# %% [markdown]
# #### LINEAR SEARCHING RANDOM NUMBER EXAMPLE ( Using BREAK )

# %%
# LINEAR SEARCHING in a Big List
# Searching for a Random Number in the list from 1 to 100

numbers = [
    47, 12, 83, 5, 29, 91, 18, 64, 37, 2,
    75, 53, 26, 99, 41, 68, 9, 57, 34, 80,
    15, 72, 1, 95, 22, 49, 88, 31, 61, 11,
    77, 44, 97, 20, 66, 39, 85, 7, 58, 25,
    93, 14, 70, 46, 100, 32, 84, 17, 55, 27,
    79, 6, 62, 43, 90, 13, 74, 36, 98, 21,
    52, 8, 87, 30, 65, 16, 94, 40, 71, 23,
    59, 4, 81, 35, 96, 10, 69, 28, 50, 76,
    19, 63, 3, 89, 45, 73, 24, 56, 92, 38,
    60, 33, 82, 54, 78, 42, 67, 86, 51, 48
]

num = int(input("Enter the Number within 1 to 100 : ") )
          
counter = 1 

for i in numbers :
    if i == 111 :
        break;
    counter += 1 
print( num , " is at the Position " , counter + 1 )
# Out:
# Enter the Number within 1 to 100 :  55
# 55  is at the Position  102

# %% [markdown]
# ### CONTINUE Statement
#
# > * #### CONTINUE Statement skips the current iterration and Immediately Value is Incremented and Loop Continues with Next Value
# > * #### For Example ,
# >      ####   if i == 20 :
# >      ####      continue;
# > * #### will skip the value 20 and increase value of i and continue from next value

# %% [markdown]
# #### Recently Maggi , Yippee! and Knorr Noodles got Banned , So , Remove those Brands from the List and Print it

# %%
noodle_brands = ["Top Ramen","Nissin Demae Ramen","Indomie","Maggi","Samyang","Shin Ramyun","Nongshim",
                 "Mama","Yippee!","Knorr","Sapporo Ichiban","Maruchan","Ottogi","Paldo","Buldak","Koka",
                "Myojo","Lucky Me!","Wai Wai","Ve Wong","Acecook","A-Sha","Ching's Secret","Cup Noodles",
                 "AnSung TangMyun","Prima Taste","Mr. Noodles","Mamee","Vifon","Baixiang"
]

for i in noodle_brands :
    if i == "Maggi" or i == "Knorr" or i == "Yippee!" :
        continue ;
    else :
        print (i)
# Out:
# Top Ramen
# Nissin Demae Ramen
# Indomie
# Samyang
# Shin Ramyun
# Nongshim
# Mama
# Sapporo Ichiban
# Maruchan
# Ottogi
# Paldo
# Buldak
# Koka
# Myojo
# Lucky Me!
# Wai Wai
# Ve Wong
# Acecook
# A-Sha
# Ching's Secret
# Cup Noodles
# AnSung TangMyun
# Prima Taste
# Mr. Noodles
# Mamee
# Vifon
# Baixiang

# %% [markdown]
# ### PASS Statement
#
# > #### PASS is Used When , We Don't want to write any Logic or Code Inside a Loop at that point ,
# > #### We can Write PASS , to Avoid Error , and Later on We can Return to the Part of the Code and Write the Logic inside it .

# %%
for i in range( 1 , 20 , 3 ):
    pass;

# %% [markdown]
# # BUILT-IN FUNCTIONS

# %% [markdown]
# ### 1. print()

# %%
print(1)
print("Leo Messi")
# Out:
# 1
# Leo Messi

# %% [markdown]
# ### 2. input() --> Used to Take Manual Input

# %%
input(" Enter Value ")
# Out:
#  Enter Value  100
# '100'

# %% [markdown]
# ### 3. type() --> Shows the Data Type

# %%
num = 23.5
type(num)
# Out:
# float

# %%
lst = [ 1, 3, 5]
type(lst)
# Out:
# list

# %% [markdown]
# ### 4. int() --> Change Data Type to Integer

# %%
int(25.77)
# Out:
# 25

# %% [markdown]
# ### 5. float() --> --> Change Data Type to Float

# %%
float( 100)
# Out:
# 100.0

# %% [markdown]
# ### 7. str() --> --> Change Data Type to String

# %%
str(25.67)
# Out:
# '25.67'

# %% [markdown]
# ### 8. list() --> Change Data Type to List

# %%
list("Leonel Messi")
# Out:
# ['L', 'e', 'o', 'n', 'e', 'l', ' ', 'M', 'e', 's', 's', 'i']

# %% [markdown]
# ### 9. tuple() --> Change Data Type to Tuple

# %%
tuple("Leonel Messi")
# Out:
# ('L', 'e', 'o', 'n', 'e', 'l', ' ', 'M', 'e', 's', 's', 'i')

# %% [markdown]
# ### 10. set() --> Change Data Type to Set

# %%
set("Leonel Messi")
# Out:
# {' ', 'L', 'M', 'e', 'i', 'l', 'n', 'o', 's'}

# %% [markdown]
# ### 11. abs() --> Absolute Value

# %%
abs(-23)
# Out:
# 23

# %% [markdown]
# ### 12. pow() --> Used for Power or Exponential Value
# ### pow ( 2 , 3 ) = 2 ^ 3

# %%
pow(2,3)
# Out:
# 8

# %%
pow ( 5 , -3)
# Out:
# 0.008

# %% [markdown]
# ### 15. min () --> Minimum Value
# ### 16. max () ---> Maximum Value

# %%
min([11 , 20 , 35 , 6])
# Out:
# 6

# %%
max((11 , 20 , 35 , 6))
# Out:
# 35

# %%
min("leonel")
# Out:
# 'e'

# %%
max("leonel")
# Out:
# 'o'

# %% [markdown]
# ### 17. round() --> Round Up the Value

# %%
round( 2543.889)
# Out:
# 2544

# %%
round( 23.44)
# Out:
# 23

# %% [markdown]
# ### 18. divmod() --> Give Integer Division Result and the Modulus Value

# %%
divmod( 100, 12)
# Out:
# (8, 4)

# %% [markdown]
# ### 19. bin() --> To Get Binary Value of a Number
# ### 20. oct() --> To Get Octal Value of a Number
# ### 21. hex() --> To Get Hexadecimal Value of a Number

# %%
bin( 245)
# Out:
# '0b11110101'

# %%
oct(245)
# Out:
# '0o365'

# %%
hex(245)
# Out:
# '0xf5'

# %% [markdown]
# ### 22. id() --> Used to Know the Address of a Parameter in the Computer Memory

# %%
val = "Leonel"
id(val)
# Out:
# 1210258458352

# %% [markdown]
# ### 23. ord() --> Provides Unicode Code or ASCII Code of a Character

# %%
ord('S')
# Out:
# 83

# %%
ord('M')
# Out:
# 77

# %% [markdown]
# ### 24. len() --> Length of a String , List , Tuple etc

# %%
len("Leonel Messi")
# Out:
# 12

# %%
noodle_brands = ["Top Ramen","Nissin Demae Ramen","Indomie","Maggi","Samyang","Shin Ramyun","Nongshim",
                 "Mama","Yippee!","Knorr","Sapporo Ichiban","Maruchan","Ottogi","Paldo","Buldak","Koka",
                "Myojo","Lucky Me!","Wai Wai","Ve Wong","Acecook","A-Sha","Ching's Secret","Cup Noodles",
                 "AnSung TangMyun","Prima Taste","Mr. Noodles","Mamee","Vifon","Baixiang"
]

len(noodle_brands)
# Out:
# 30

# %% [markdown]
# ### 25. sum() --> Returns the Sum of Values ( List , Tuple etc)

# %%
numbers = [
    3, 8, 12, 19, 24, 31, 37, 42, 48, 53,
    57, 61, 66, 72, 75, 81, 86, 90, 94, 99,
    102, 105, 108, 110, 111, 118, 124, 131, 139, 147,
    156, 163, 171, 184, 192, 205, 217, 229, 241, 256,
    268, 279, 291, 314, 336, 359, 387, 421, 456, 498
]

sum( numbers)
# Out:
# 7876

# %% [markdown]
# ### 26. help () --> Used to Get Information about Any Function or Keyword

# %%
help(ord)
# Out:
# Help on built-in function ord in module builtins:
#
# ord(c, /)
#     Return the Unicode code point for a one-character string.

# %% [markdown]
# # MODULES
# > ### Consider Modules to be Same as Code Library
# > ### A File Containing a Set of Functions that You Want to Include in Your Application.
# > ### Examples of Python Modules :
# > * #### Math
# > * #### Random
# > * #### OS
# > * #### time etc

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# C:\Users\Shubhayu\IdeaProjects\My_Fresh_Py_Proj_1\.venv\lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# 1                   ast                 ipykernel           reprlib
# 111                 asttokens           ipykernel_launcher  requests
# 123                 async_lru           isoduration         rfc3339_validator
# Capstone_proj_1_MSServer_S3_Migration asynchat            itertools           rfc3986_validator
# Demo_py             asyncio             jedi                rfc3987_syntax
# IPython             asyncore            jinja2              rlcompleter
# __future__          atexit              jmespath            rpds
# _abc                attr                json                runpy
# _aix_support        attrs               json5               s3transfer
# ...

# %%
import math
import pandas 
import random

# %% [markdown]
# > #### Write the Module or Library Name and then
# > #### After " . " Press Tab to see All the Functions Available within that Module
# > #### e.g. - After math. Press Tab to see all the Func.s in Math

# %%
math.
pandas.
random.

# %% [markdown]
# # STRINGS
# > #### Strings are Sequence of Characters.
# > #### In Python Specifically Strings are Sequence of Unicode Characters.

# %% [markdown]
# ## CREATING STRINGS

# %%
str_1 = "Leo Messi" # With Double Quotes
print(str_1)
# Out:
# Leo Messi

# %%
str_1 = 'Leo Messi' # With Single Quotes
print(str_1)
# Out:
# Leo Messi

# %%
str_1 = '''Leo Messi''' # With Triple Quotes --> USED FOR MULTI-LINE STRINGS
print(str_1)
# Out:
# Leo Messi

# %%
str_1 = """Leo Messi""" # With Triple Double Quotes --> USED FOR MULTI-LINE STRINGS
print(str_1)
# Out:
# Leo Messi

# %%
# str_1 = 'Today is Messi's Birthday' --> it will Throw Error as Sentence Contains ' 

str_1 = " Today is Messi's Birthday"
print(str_1)
# Out:
#  Today is Messi's Birthday

# %% [markdown]
# #### MULTI-LINE STRINGS

# %%
text = """
Artificial Intelligence (AI) is transforming the way people interact with technology.
From virtual assistants and recommendation systems to autonomous vehicles and medical
diagnosis, AI has become an integral part of modern life.

Machine Learning (ML), a subset of AI, enables computers to learn patterns from data
without being explicitly programmed. Deep Learning, a specialized branch of ML, uses
artificial neural networks with multiple layers to solve complex problems such as image
recognition, natural language processing, and speech synthesis.

"""

print(text)
# Out:
# Artificial Intelligence (AI) is transforming the way people interact with technology.
# From virtual assistants and recommendation systems to autonomous vehicles and medical
# diagnosis, AI has become an integral part of modern life.
#
# Machine Learning (ML), a subset of AI, enables computers to learn patterns from data
# without being explicitly programmed. Deep Learning, a specialized branch of ML, uses
# artificial neural networks with multiple layers to solve complex problems such as image
# recognition, natural language processing, and speech synthesis.

# %%
text = '''
Artificial Intelligence (AI) is transforming the way people interact with technology.
From virtual assistants and recommendation systems to autonomous vehicles and medical
diagnosis, AI has become an integral part of modern life.

Machine Learning (ML), a subset of AI, enables computers to learn patterns from data
without being explicitly programmed. Deep Learning, a specialized branch of ML, uses
artificial neural networks with multiple layers to solve complex problems such as image
recognition, natural language processing, and speech synthesis.

'''

print(text)
# Out:
# Artificial Intelligence (AI) is transforming the way people interact with technology.
# From virtual assistants and recommendation systems to autonomous vehicles and medical
# diagnosis, AI has become an integral part of modern life.
#
# Machine Learning (ML), a subset of AI, enables computers to learn patterns from data
# without being explicitly programmed. Deep Learning, a specialized branch of ML, uses
# artificial neural networks with multiple layers to solve complex problems such as image
# recognition, natural language processing, and speech synthesis.

# %% [markdown]
# ## ACCESSING THE STRINGS

# %% [markdown]
# ### INDEXING

# %%
str_1 = 'Leo Messi'
print(str_1)
# Out:
# Leo Messi

# %%
print(str_1[0])
print(str_1[2])
print(str_1[6])
print(str_1[8])
# Out:
# L
# o
# s
# i

# %% [markdown]
# ### TYPES of INDEXING
# > * #### POSITIVE INDEXING ( From 0 to n , From Left to Right )
# > * #### NEGATIVE INDEXING ( From -1 to -n , From Right to left )

# %%
str_1 = 'Leo Messi'
print(str_1)
# Out:
# Leo Messi

# %%
print(str_1[-1])
print(str_1[-3])
print(str_1[-5])
print(str_1[-7])
# Out:
# i
# s
# M
# o

# %% [markdown]
# ## SLICING of STRINGS

# %%
str_1 = 'Leo Messi'
print(str_1)
# Out:
# Leo Messi

# %%
print(str_1[0:5]) # 1st Index , Last Index
# Out:
# Leo M

# %%
print(str_1[:5]) # 1st Index by Default 0 , if Not Mentioned
# Out:
# Leo M

# %%
print(str_1[2:]) # Last Index by Default Last Character or Last Element , if Not Mentioned
# Out:
# o Messi

# %%
print(str_1[2:-3]) # Combination of Positive and Negative Index
# Out:
# o Me

# %%
print(str_1[-3:]) # Combination of Positive and Negative Index
# Out:
# ssi

# %%
print(str_1[:-2]) # Combination of Positive and Negative Index
# Out:
# Leo Mes

# %%
print(str_1[-5:-2]) # Both Negative Index
# Out:
# Mes

# %%
print(str_1[:])
# Out:
# Leo Messi

# %%
print(str_1[2:8:2]) # 1st Index , Last Index , Steps ( Gaps)
# Out:
# oMs

# %% [markdown]
# #### STRINGS are IMMUTABLE Like TUPLE

# %%
str_1 = "Leonel"
print(str_1)
# Out:
# Leonel

# %% [markdown]
# #### Showing Error As It is IMMUTABLE ( CANNOT MODIFY A STRING AFTER INITIATION)

# %%
str_1[2] = 'x' ## Showing Error As It is IMMUTABLE
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 str_1[2] = 'x' ## Showing Error As It is IMMUTABLE
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ##  DELETION of STRING

# %%
name = 'Leo'
print(name)
# Out:
# Leo

# %%
del name ## DELETING The STRING

# %% [markdown]
# #### The String is No Longer There

# %%
print(name) ## The String is No Longer There
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 print(name) ## The String is No Longer There
#
# NameError: name 'name' is not defined

# %%
name = 'Leo'
print(name)
# Out:
# Leo

# %% [markdown]
#  #### DELETION Of SPECIFIC CHARACTER IS NOT ALLOWED , as STRINGS ARE IMMUTABLE

# %%
del name[2] ## DELETION Of SPECIFIC CHARACTER IS NOT ALLOWED , as STRINGS ARE IMMUTABLE
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 del name[2]
#
# TypeError: 'str' object doesn't support item deletion

# %%
del name[2:6]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 del name[2:6]
#
# TypeError: 'str' object does not support item deletion

# %% [markdown]
# ## STRING OPERATIONS

# %% [markdown]
# ### 1. ARITHMATIC OPERATIONS

# %% [markdown]
# #### i. CONCATINATION of STRINGS

# %%
'Leo' + '-' + 'Messi'+'-'+'LM10'
# Out:
# 'Leo-Messi-LM10'

# %% [markdown]
# #### ii. MULTIPLICATION of STRINGS

# %%
'Leo'* 4
# Out:
# 'LeoLeoLeoLeo'

# %%
'Leo'*3+'Messi'*3
# Out:
# 'LeoLeoLeoMessiMessiMessi'

# %% [markdown]
# ### 2. RELATIONAL OPERATORS

# %%
'Hello' == 'Messi'
# Out:
# False

# %%
'Hello' != 'Messi'
# Out:
# True

# %% [markdown]
# #### This Comparison is Lexiographically , as Hello Comes before Messi in Dictionary , So Hello < Messi

# %%
'Hello' > 'Messi' ## This Comparison is Lexiographically , as Hello Comes before Messi in Dictionary , So Hello < Messi
# Out:
# False

# %% [markdown]
# #### This Comparison is Lexiographically , as Leo Comes After Christiano in Dictionary , So Leo > Christiano

# %%
'Leo' > 'Christiano' ## This Comparison is Lexiographically , as Leo Comes After Christiano in Dictionary , So Leo > Christiano
# Out:
# True

# %% [markdown]
# #### Upper Case Letters Comes Before Lower Case Letters in Dictionary , So , Leo < leo

# %%
'leo' < 'Leo' ## Upper Case Letters Comes Before Lower Case Letters in Dictionary , So , Leo < leo
# Out:
# False

# %% [markdown]
# ## LOGICAL OPERATORS

# %% [markdown]
# #### In Python,
# #### EMPTY STRINGS --> False
# ####  NON EMPTY STRINGS --> True

# %% [markdown]
# #### 0 and 1 --> 0 , so , Empty String as OUTPUT

# %%
"" and "leo" ## 0 and 1 --> 0 , so , Empty String as OUTPUT
# Out:
# ''

# %% [markdown]
# #### 0 or 1 --> 1 , so , Non Empty String as OUTPUT

# %%
"" or "leo"
# Out:
# 'leo'

# %%
"messi" or "leo"
# Out:
# 'messi'

# %%
"messi" and "leo"
# Out:
# 'leo'

# %% [markdown]
# #### Negation of Non Empty String is Empty String , So Getting FALSE
# #### Negation of Empty String is Non Empty String , So Getting TRUE

# %%
not 'Leo'
# Out:
# False

# %%
not ''
# Out:
# True

# %% [markdown]
# ## LOOP OPERATORS

# %%
name = 'Leo Messi'
for i in name:
    print(i)
# Out:
# L
# e
# o
#
# M
# e
# s
# s
# i

# %%
name = 'Leo Messi the G.O.A.T'
for i in name[1:20:3]:
    print(i)
# Out:
# e
# M
# s
# t
#
# O
# .

# %% [markdown]
# ## FUNCTIONS

# %% [markdown]
# ### 1. COMMON FUNCTIONS
# * #### len()
# * #### max()
# * #### min()
# * #### sorted()

# %%
name = 'LeonelMessi'
len(name)
# Out:
# 11

# %% [markdown]
# #### Returning Max and Min Value as per ASCII Value of the Characters

# %%
max(name) # Returning Max Value as per ASCII Value of the Characters
# Out:
# 's'

# %%
min(name)
# Out:
# 'L'

# %% [markdown]
# #### Ascending Order Sorting

# %%
sorted(name)
# Out:
# ['L', 'M', 'e', 'e', 'e', 'i', 'l', 'n', 'o', 's', 's']

# %% [markdown]
# #### REVERSE SORTING Of STRINGS

# %%
sorted(name, reverse = True)
# Out:
# ['s', 's', 'o', 'n', 'l', 'i', 'e', 'e', 'e', 'M', 'L']

# %% [markdown]
# ### 2.
# * ### Capitalize() --> Turns the 1st Character into Upper Case

# %%
str = 'leonardo'
str.capitalize()
# Out:
# 'Leonardo'

# %%
'i love leonel messi'.capitalize()
# Out:
# 'I love leonel messi'

# %% [markdown]
# * ### Title() --> Turns 1st Alphabet of Each Word into Upper Case

# %%
'i love leonel messi'.title()
# Out:
# 'I Love Leonel Messi'

# %% [markdown]
# * ### Upper() --> Turns All Letters into Upper Case

# %%
'i love leonel messi'.upper()
# Out:
# 'I LOVE LEONEL MESSI'

# %% [markdown]
# * ### Lower() --> Turns All Letters into Lower Case

# %%
'i love leonel messi'.lower()
# Out:
# 'i love leonel messi'

# %% [markdown]
# * ### Swapcase() --> Turns Lower Cases Into Upper Case and Upper Cases into Lower Case

# %%
'i love leonel messi'.swapcase()
# Out:
# 'I LOVE LEONEL MESSI'

# %%
'lEonELmeSSi'.swapcase()
# Out:
# 'LeONelMEssI'

# %% [markdown]
# ### 3. COUNT() --> Counts How Many Times a Sub-String is Repeated in a Whole String , List or Tuple

# %%
txt = ' I am a Huge Fan of Messi. Messi won 8 Ballon Dor. I have decided to make a Messi Sketch and send it to him'
txt.count('Messi')
# Out:
# 3

# %% [markdown]
# ### 4.  FIND() / INDEX () --> Helps Finding a Sub-String in a Big String , List

# %%
txt = ' I am a Huge Fan of Messi. Messi won 8 Ballon Dor. I have decided to make a Messi Sketch and send it to him'
txt.find('Ballon Dor')
# Out:
# 39

# %%
txt = ' I am a Huge Fan of Messi. Messi won 8 Ballon Dor. I have decided to make a Messi Sketch and send it to him'
txt.index('Ballon Dor')
# Out:
# 39

# %% [markdown]
# ### 5. Startswith () / Endswith () --> Helps Finding Whether a A String Starts with a Specific Sub-String or Not

# %%
txt = 'I am a Huge Fan of Messi. Messi won 8 Ballon Dor. I have decided to make a Messi Sketch and send it to him'
txt.startswith('x')
# Out:
# False

# %%
txt.startswith('I')
# Out:
# True

# %%
txt.endswith('x')
# Out:
# False

# %%
txt.endswith('m')
# Out:
# True

# %% [markdown]
# ### 6. FORMAT() --> Used to Assign Values to the Empty Substrings in a Text Later in an Order

# %%
" I am a Young Boy , who loves to eat {} while watching {}".format('Popcorn','Movie')
# Out:
# ' I am a Young Boy , who loves to eat Popcorn while watching Movie'

# %%
" I am a Young Boy , who loves to eat {1} while watching {0}".format('Popcorn','Movie')
# Out:
# ' I am a Young Boy , who loves to eat Movie while watching Popcorn'

# %%
" I am a Young Boy , who loves to eat {food} while watching {show}".format(food = 'Popcorn',show = 'Movie')
# Out:
# ' I am a Young Boy , who loves to eat Popcorn while watching Movie'

# %% [markdown]
# ### 7.
# ### isalnum() --> Whether ALL Characters are Alpha Numeric or Not|

# %%
'AX*&%_23B'.isalnum()
# Out:
# False

# %%
'A234XB'.isalnum()
# Out:
# True

# %% [markdown]
# ### isalpha() --> Whether ALL Characters are Alpha Numeric or Not

# %%
'AX*&%_23B'.isalpha()
# Out:
# False

# %%
'AklxgB'.isalpha()
# Out:
# True

# %% [markdown]
# ### isdecimal() --> Whether ALL Characters are Decimal or Not

# %%
'12gf56'.isdecimal()
# Out:
# False

# %%
'120056'.isdecimal()
# Out:
# True

# %% [markdown]
# ### isdigit() --> Whether ALL Characters are Digits or Not

# %%
'12gf56'.isdigit()
# Out:
# False

# %%
'120056'.isdigit()
# Out:
# True

# %% [markdown]
# ### isidentifier() --> Whether it is a Valid Identifier or Not

# %%
'first name'.isidentifier()
# Out:
# False

# %%
'first_name'.isidentifier()
# Out:
# True

# %% [markdown]
# ### 8. split() --> Splits a String into Seperate Parts

# %%
"My Name is Micheal Jackson".split()
# Out:
# ['My', 'Name', 'is', 'Micheal', 'Jackson']

# %%
"My Name is Micheal Jackson".split("is")
# Out:
# ['My Name ', ' Micheal Jackson']

# %%
"My Name is Micheal Jackson".split("M")
# Out:
# ['', 'y Name is ', 'icheal Jackson']

# %% [markdown]
# ### 9. join() --> Joining a List with respect to particular Element

# %%
" ".join(['My', 'Name', 'is', 'Micheal', 'Jackson'])
# Out:
# 'My Name is Micheal Jackson'

# %%
"--".join(['My', 'Name', 'is', 'Micheal', 'Jackson'])
# Out:
# 'My--Name--is--Micheal--Jackson'

# %%
"||".join(['My', 'Name', 'is', 'Micheal', 'Jackson'])
# Out:
# 'My||Name||is||Micheal||Jackson'

# %% [markdown]
# ### 10. repalce() --> Replace a Sub-String by Other Substring

# %%
"My Name is Micheal Jackson".replace("Micheal", "Daniel")
# Out:
# 'My Name is Daniel Jackson'

# %% [markdown]
# ### 11.
# > ### strip() --> Strips Off Trailing ( left) and Leading Spaces (right)
# > ### lstrip() --> Strips off Left Spaces
# > ### rstrip () --> Stripc off Right Spaces

# %%
"      My Name is Micheal Jackson    ".strip()
# Out:
# 'My Name is Micheal Jackson'

# %%
"      My Name is Micheal Jackson    ".lstrip()
# Out:
# 'My Name is Micheal Jackson    '

# %%
"      My Name is Micheal Jackson    ".rstrip()
# Out:
# '      My Name is Micheal Jackson'

# %% [markdown]
# ## LIST

# %% [markdown]
# ### LIST Vs ARRAY
# * #### Array is Homogeneous , and LIST is Heterogeneous
# * #### In Array Data is Stored inside Continuous Memory Location , But, In Case of Lists it is Not the Case .
# * #### Arrays are Much Faster
# * #### LISTS are Programmer Friendly

# %% [markdown]
# ## CREATING LISTS

# %% [markdown]
# * #### Empty List and Homogeneous List

# %%
lst = [] # Empty List Creation

lst_1 = [ 1 , 2, 3, 4, 5 ] #Homogeneous List

print(lst)
print(lst_1)
# Out:
# []
# [1, 2, 3, 4, 5]

# %% [markdown]
# * #### Creation of Heterogeneous List

# %%
lst = [ 11 , 'Messi' , True , 25.9 , 34 + 7j ] # Creating Heterogeneous List

print(lst)
# Out:
# [11, 'Messi', True, 25.9, (34+7j)]

# %% [markdown]
# * #### Creation of 2D LIST

# %%
lst = [ 1,4,7, [7,8,9]]

print(lst)
# Out:
# [1, 4, 7, [7, 8, 9]]

# %% [markdown]
# * #### Creation of 3D List

# %%
lst = [ [[ 11, 23] ,[34, 45]] , [[ 36, 78], [89,23]] ]

print(lst)
# Out:
# [[[11, 23], [34, 45]], [[36, 78], [89, 23]]]

# %% [markdown]
# ### LIST Function

# %%
list('Messi')
# Out:
# ['M', 'e', 's', 's', 'i']

# %% [markdown]
# #### List Operations

# %%
str_1 = 'Messi is My Boss'
lst_1 = list(str_1)

print(lst_1)

print(lst_1[1])
print(lst_1[4])
print(lst_1[-3])

print(lst_1[ 2: 10])
print(lst_1[ -13 : -5])

print(lst_1 [:])
print(lst_1 [ 4:])
print(lst_1 [:6])
# Out:
# ['M', 'e', 's', 's', 'i', ' ', 'i', 's', ' ', 'M', 'y', ' ', 'B', 'o', 's', 's']
# e
# i
# o
# ['s', 's', 'i', ' ', 'i', 's', ' ', 'M']
# ['s', 'i', ' ', 'i', 's', ' ', 'M', 'y']
# ['M', 'e', 's', 's', 'i', ' ', 'i', 's', ' ', 'M', 'y', ' ', 'B', 'o', 's', 's']
# ['i', ' ', 'i', 's', ' ', 'M', 'y', ' ', 'B', 'o', 's', 's']
# ['M', 'e', 's', 's', 'i', ' ']

# %% [markdown]
# #### 2D List Operations

# %%
lst = [ 1,4,7, [7,8,9]]

print(lst)

print(lst[3][1])
print(lst[3][2])
# Out:
# [1, 4, 7, [7, 8, 9]]
# 8
# 9

# %% [markdown]
# #### 3D LIST OPERATIONS
#
# > * #### Indexing is impoartant :
# >
# > * #### [[ 11, 23] ,[34, 45]] is [ 0 ] Index , and [[ 36, 78], [89,23]] is [ 1 ] Index Suppose
# >
# > * #### Then 2nd Index of the List [ 11, 23] is [ 0 ] and [34, 45] ia [ 1 ] again ,
# >
# > * #### then within that List 11 is [ 0 ] and 23 is [ 1 ] .

# %%
lst = [ [[ 11, 23] ,[34, 45]] , [[ 36, 78], [89,23]] ]
print(lst)

print(lst[1][1][0])
# Out:
# [[[11, 23], [34, 45]], [[36, 78], [89, 23]]]
# 89

# %% [markdown]
# ### LISTS are Mutable

# %%
lst_1 = [ 1 , 2, 3, 4, 5 ] 

print(lst_1)

lst_1[2] = 200

print(lst_1)
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 200, 4, 5]

# %% [markdown]
# #### Slicing and Modifying the Values

# %%
lst_1[1:3] = [100, 200, 300]
print(lst_1)
# Out:
# [1, 100, 200, 300, 4, 5]

# %% [markdown]
# ### ADDING One ELEMENT at the End of LIST Using APPEND ( )

# %%
lst_1.append(2500)

# %%
print(lst_1)
# Out:
# [1, 100, 200, 300, 4, 5, 2500]

# %% [markdown]
# ### ADDING MULTIPLE ELEMENTS AT THE END OF THE LIST Using EXTEND ( )

# %%
lst_1.extend([1500, 3400, 5600, 7890]) # It is Like Adding Another List of Values at the end of the List
print(lst_1)
# Out:
# [1, 100, 200, 300, 4, 5, 2500, 1500, 3400, 5600, 7890]

# %% [markdown]
# ### ADDING A LIST of VALUES at the END of the LIST Using APPEND

# %%
lst_1.append([600, 890, 766])
print(lst_1)
# Out:
# [1, 100, 200, 300, 4, 5, 2500, 1500, 3400, 5600, 7890, [600, 890, 766]]

# %% [markdown]
# >### IF a String is ADDED Using EXTEND ( ) at the End of the List ,
# > ### The STRING is Converted Into LIST and Then ADDED at the END

# %%
lst_1.extend('Leo Messi')

# %%
print(lst_1)
# Out:
# [1, 100, 200, 300, 4, 5, 2500, 1500, 3400, 5600, 7890, [600, 890, 766], 'L', 'e', 'o', ' ', 'M', 'e', 's', 's', 'i']

# %% [markdown]
# ### ADDING ELEMENTS at ANY POSITION In the LIST Using INSERT( )
# > #### INSERT takes Two Arguments , INSERT ( Index Position , Element to be ADDED)

# %%
lst_1.insert( 5 , 400)
lst_1.insert( 17 , 'X')

print(lst_1)
# Out:
# [1, 100, 200, 300, 4, 400, 5, 2500, 1500, 3400, 5600, 7890, [600, 890, 766], 'L', 'e', 'o', ' ', 'X', 'M', 'e', 's', 's', 'i']

# %% [markdown]
# ## DELETION OPERATION on LIST

# %% [markdown]
# ### DELETING Specific Element from a LIST Using del ( )

# %%
del lst_1[5]

# %%
print(lst_1)
# Out:
# [1, 100, 200, 300, 4, 5, 2500, 1500, 3400, 5600, 7890, [600, 890, 766], 'L', 'e', 'o', ' ', 'X', 'M', 'e', 's', 's', 'i']

# %%
del lst_1[ 10]

# %%
print(lst_1)
# Out:
# [1, 100, 200, 300, 4, 5, 2500, 1500, 3400, 5600, [600, 890, 766], 'L', 'e', 'o', ' ', 'X', 'M', 'e', 's', 's', 'i']

# %% [markdown]
# ### DELETING  the Whole LIST Using del ( )

# %%
del lst_1

# %%
print(lst_1) # Throwing Error as the List is No Longer There
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 print(lst_1)
#
# NameError: name 'lst_1' is not defined

# %%
lst = [1, 100, 200, 300, 4, 5, 2500, 1500, 3400, 5600, [600, 890, 766], 'L', 'e', 'o', ' ', 'X', 'M', 'e', 's', 's', 'i']

# %% [markdown]
# ### Want to DELETE M , E, S , S, I from LIST
# > #### We Can Use SLINCING While DELETING Here

# %%
del lst [-5: ]

print(lst)
# Out:
# [1, 100, 200, 300, 4, 5, 2500, 1500, 3400, 5600, [600, 890, 766], 'L', 'e', 'o', ' ', 'X']

# %% [markdown]
# ### DELETION OF SPECIFIC Element Using REMOVE ( )

# %%
lst.remove(3400)

# %%
print(lst)
# Out:
# [1, 100, 200, 300, 4, 5, 2500, 1500, 5600, [600, 890, 766], 'L', 'e', 'o', ' ', 'X']

# %%
lst.remove('X')

# %%
print(lst)
# Out:
# [1, 100, 200, 300, 4, 5, 2500, 1500, 5600, [600, 890, 766], 'L', 'e', 'o', ' ']

# %% [markdown]
# ### DELETING the Last Element Using POP ( )

# %%
lst.pop( )
# Out:
# ' '

# %%
print(lst)
# Out:
# [1, 100, 200, 300, 4, 5, 2500, 1500, 5600, [600, 890, 766], 'L', 'e', 'o']

# %%
msg = lst.pop()

# %%
print(msg)
print(lst)
# Out:
# o
# [1, 100, 200, 300, 4, 5, 2500, 1500, 5600, [600, 890, 766], 'L', 'e']

# %%
### DELETING Any Specific Element Using POP ( )

# %%
lst .pop(5)
# Out:
# 5

# %%
msg = lst.pop( 10)

# %%
print(msg)
print(lst)
# Out:
# e
# [1, 100, 200, 300, 4, 2500, 1500, 5600, [600, 890, 766], 'L']

# %%
animal = [ 'lion' , 'eagle' ,'grizzly bear', 'horse' , 'panda', 'monkey' , 'elephant' , 'hippo' , 'rhino' , 'gaur' , 'bison']

print(animal)
# Out:
# ['lion', 'eagle', 'grizzly bear', 'horse', 'panda', 'monkey', 'elephant', 'hippo', 'rhino', 'gaur', 'bison']

# %% [markdown]
# ## RUNNING LOOPS on LIST

# %%
for val in animal :
    print (val)
# Out:
# lion
# eagle
# grizzly bear
# horse
# panda
# monkey
# elephant
# hippo
# rhino
# gaur
# bison

# %%
for val in animal: 
    if val == 'lion':
        print('The King of the Jungle is : ' , val)
    elif val == 'grizzly bear':
        print('The One Who can Hunt Tiger is : ' , val)
    elif val == 'elephant':
        print(' The Real Titan of the Jungle is : ' , val) 
    else :
        if val == 'bison' or val == 'rhino' or val == 'hippo' or val == 'gaur':
            print( ' The Herbivorous Giant is : ' , val)
        else: 
            print ( val , ' is a Normal Creature')
# Out:
# The King of the Jungle is :  lion
# eagle  is a Normal Creature
# The One Who can Hunt Tiger is :  grizzly bear
# horse  is a Normal Creature
# panda  is a Normal Creature
# monkey  is a Normal Creature
#  The Real Titan of the Jungle is :  elephant
#  The Herbivorous Giant is :  hippo
#  The Herbivorous Giant is :  rhino
#  The Herbivorous Giant is :  gaur
#  The Herbivorous Giant is :  bison

# %% [markdown]
# ## BUILT IN FUNCTIONS on LIST

# %% [markdown]
# > ### len( ) --> Determines the length of the List
# > ### min( ) --> Determines the Minimum value or Lexiographically ( Dictionary) the Smallest Element
# > ### max( ) -->  Determines the Minimum value or Lexiographically the Largest Element

# %%
animal = [ 'lion' , 'eagle' ,'grizzly bear', 'horse' , 'panda', 'monkey' , 'elephant' , 'hippo' , 'rhino' , 'gaur' , 'bison']

print(animal)
# Out:
# ['lion', 'eagle', 'grizzly bear', 'horse', 'panda', 'monkey', 'elephant', 'hippo', 'rhino', 'gaur', 'bison']

# %%
len ( animal)
# Out:
# 11

# %%
min( animal)
# Out:
# 'bison'

# %%
max ( animal)
# Out:
# 'rhino'

# %% [markdown]
# ## SORTING ELEMENTS of LIST

# %% [markdown]
# > ### sorted ( ) --> Temporarily Sorting the List
# > ### sort ( ) --> Temporarily Sorting the List
# > ### Set Reverse = True -- > to Sort in Reverse Order

# %%
sorted ( animal)
# Out:
# ['bison',
#  'eagle',
#  'elephant',
#  'gaur',
#  'grizzly bear',
#  'hippo',
#  'horse',
#  'lion',
#  'monkey',
#  'panda',
#  'rhino']

# %%
sorted ( animal , reverse = True )
# Out:
# ['rhino',
#  'panda',
#  'monkey',
#  'lion',
#  'horse',
#  'hippo',
#  'grizzly bear',
#  'gaur',
#  'elephant',
#  'eagle',
#  'bison']

# %%
animal.sort()

# %%
print( animal)
# Out:
# ['bison', 'eagle', 'elephant', 'gaur', 'grizzly bear', 'hippo', 'horse', 'lion', 'monkey', 'panda', 'rhino']

# %%
animal.sort(reverse = True)
print ( animal )
# Out:
# ['rhino', 'panda', 'monkey', 'lion', 'horse', 'hippo', 'grizzly bear', 'gaur', 'elephant', 'eagle', 'bison']

# %% [markdown]
# ### INDEX ( ) --> To Determine the Index of an Element in the LIST

# %%
animal.index('lion')
# Out:
# 3

# %%
animal.index('grizzly bear')
# Out:
# 6

# %% [markdown]
# > ## Suppose title( ) Function is Not There is Python , Then How to Perform the Function , Or Manually Create the Function

# %%
str = ' I love You Leonel Messi. You are the God of Football'

print(str)
# Out:
#  I love You Leonel Messi. You are the God of Football

# %%
str.split()
# Out:
# ['I',
#  'love',
#  'You',
#  'Leonel',
#  'Messi.',
#  'You',
#  'are',
#  'the',
#  'God',
#  'of',
#  'Football']

# %%
for i in str.split() :
    print(i.capitalize())
# Out:
# I
# Love
# You
# Leonel
# Messi.
# You
# Are
# The
# God
# Of
# Football

# %%
print(''.join(str))
# Out:
#  I love You Leonel Messi. You are the God of Football

# %% [markdown]
# > ### You Got One Email ID , Now Display the string or name before @
# >
# > ####   FIND the @ position using find('@')
# > #### Then SLICE the String with Respect to that Index Position and
#
# > #### Display Substring Before that Position [ : ( Index of @ )]

# %%
mail = input('Enter Your Mail ID  : ')

print( mail[ : mail.find('@')])
# Out:
# Enter Your Mail ID  :  rammohan@gmail.com
# rammohan

# %% [markdown]
# ### Remove Duplicates from a STRING

# %%
lst = [ 1 ,2,2, 4 , 5, 7, 4, 6, 9, 9, 6, 2, 3, 0,6]
print(lst)
# Out:
# [1, 2, 2, 4, 5, 7, 4, 6, 9, 9, 6, 2, 3, 0, 6]

# %%
ls = [] 
for i in lst :
    if i not in ls :
        ls.append (i)

print(ls)
# Out:
# [1, 2, 4, 5, 7, 6, 9, 3, 0]

# %% [markdown]
# ## TUPLES

# %% [markdown]
# ### CREATING a TUPLE

# %% [markdown]
# #### HOMOGENEOUS TUPLE

# %%
tpl = ( 1 , 34, 56, 78, 23) 
print(tpl)
# Out:
# (1, 34, 56, 78, 23)

# %% [markdown]
# #### HETEROGENEOUS TUPLE

# %%
tpl = ( 12, True , 34.6, 34+78j , 'Messi')
print(tpl)
# Out:
# (12, True, 34.6, (34+78j), 'Messi')

# %% [markdown]
# > #### IF We Simply Write a Single Element within ( ) , Type ( ) will Show INT Data Type ,
# > #### We Need to ADD a Comma ( , ) To Get TUPLE as Data Type

# %%
tpl= ( 23)
type(tpl)
# Out:
# int

# %%
tpl = ( 23 ,)
type(tpl)
# Out:
# tuple

# %% [markdown]
# ### TUPLE ( ) Function --> Used to Change a Data into TUPLE

# %%
str = 'Leonel Messi'
tuple(str)
# Out:
# ('L', 'e', 'o', 'n', 'e', 'l', ' ', 'M', 'e', 's', 's', 'i')

# %%
lst = [19,73,77,82,92,2,77,29,92,62]

tuple(lst)
# Out:
# (19, 73, 77, 82, 92, 2, 77, 29, 92, 62)

# %% [markdown]
# ### ACCESSING a TUPLE

# %%
tpl = (19,73,77,82,92,25,77,29,92,62)

# %%
tpl[1]
# Out:
# 73

# %%
tpl [-5]
# Out:
# 25

# %%
tpl[ 2: 8]
# Out:
# (77, 82, 92, 25, 77, 29)

# %%
tpl[:6]
# Out:
# (19, 73, 77, 82, 92, 25)

# %%
tpl[4:]
# Out:
# (92, 25, 77, 29, 92, 62)

# %%
tpl[ -5 :]
# Out:
# (25, 77, 29, 92, 62)

# %% [markdown]
# ### 2D TUPLE CREATION

# %%
tpl = ( 12, 34, 56 , ( 6 , 75))
print(tpl)
# Out:
# (12, 34, 56, (6, 75))

# %% [markdown]
# ### ACCESSING 2D TUPLE

# %%
tpl[-1][1]
# Out:
# 75

# %%
tpl[-1][0]
# Out:
# 6

# %% [markdown]
# ### 3D TUPLE CREATION

# %%
tpl = ( (( 34, 56) , ( 6 , 75)) , (( 26, 43) , ( 67, 38)) )
print(tpl)
# Out:
# (((34, 56), (6, 75)), ((26, 43), (67, 38)))

# %% [markdown]
# ### ACCESSING 3D TUPLE

# %%
tpl[-1][-2][-2]
# Out:
# 26

# %%
tpl[-2] [0] [1]
# Out:
# 56

# %% [markdown]
# ## EDITING TUPLE
# ## " TUPLE ARE IMMUTABLE"  --> Just Like STRINGS
# ### RULES:
# > ### TUPLES Are READ-ONLY Data Type
# > * #### Can NOT MODIFY TUPLE
# > * #### Can NOT DELETE Specific ELEMENT from TUPLE
# > * #### Can NOT ADD ELEMENTS to TUPLE

# %%
tpl = (19,73,77,82,92,25,77,29,92,62)

# %%
tpl[ 3] = 56
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[161], line 1
# ----> 1 tpl[ 3] = 56
#
# TypeError: 'tuple' object does not support item assignment

# %%
del tpl[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[162], line 1
# ----> 1 del tpl[2]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
tpl.append(23)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[163], line 1
# ----> 1 tpl.append(23)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# ### OPERATIONS on TUPLE

# %%
tpl = ( 1, 4, 6, 8)
tpl_2 = ( 2, 5, 8, 9)

# %%
tpl + tpl_2
# Out:
# (1, 4, 6, 8, 2, 5, 8, 9)

# %%
tpl * 5
# Out:
# (1, 4, 6, 8, 1, 4, 6, 8, 1, 4, 6, 8, 1, 4, 6, 8, 1, 4, 6, 8)

# %% [markdown]
# ### LOOPS on TUPLE

# %%
for i in tpl:
    print(i)
# Out:
# 1
# 4
# 6
# 8

# %%
5 in tpl_2
# Out:
# True

# %%
5 in tpl
# Out:
# False

# %% [markdown]
# ### FUNCTIONS on TUPLE --> len ( ) , min ( ) , Max ( ) , Sum ( ) , Sorted ( )

# %%
len(tpl)
# Out:
# 4

# %%
min(tpl)
# Out:
# 1

# %%
max(tpl)
# Out:
# 8

# %%
sum(tpl)
# Out:
# 19

# %%
sorted(tpl)
# Out:
# [1, 4, 6, 8]

# %%
sorted(tpl, reverse = True)
# Out:
# [8, 6, 4, 1]

# %% [markdown]
# ## SETS
# ### RULES:
# > ### 1. SETS Do NOT Allow DUPLECATES
# >
# > ### 2. SETS Have NO INDEXING / SLICING
# >
# > ### 3. SETS Do NOT Allow MUTABLE Data Type
# >
# > ### 4. SET Itself is a MUTABLE Data Type

# %% [markdown]
# ### CREATING SET

# %% [markdown]
# #### For CREATING EMPTY SET If We Write st = { } , By Default the Type is Shown as DICTIONARY ,
# #### So , For CREATING EMPTY SET , We need to Write ,
# > ### st = set()

# %%
st = {} 
type( st)
# Out:
# dict

# %%
st = set()
type(st)
# Out:
# set

# %% [markdown]
# ### HOMOGENEOUS SET

# %%
st = { 12, 45, 56, 87}
print(st)
# Out:
# {56, 12, 45, 87}

# %% [markdown]
# ### HETEROGENEOUS SET

# %%
st = { 12, True , 34.6 , 23+7j , 'Leo Messi'}
print ( st)
# Out:
# {True, 34.6, 'Leo Messi', (23+7j), 12}

# %% [markdown]
# ### DUPLECATE RECORDS DON'T SHOW or NOT ALLOWED in SETS

# %%
st = { 1 ,1,1, 3,3,5,6,6,7,7,7,8}
print(st)
# Out:
# {1, 3, 5, 6, 7, 8}

# %% [markdown]
# ### SETS Do NOT Allow MUTABLE Data Type
#
# > #### IF We Enter , MUTABLE DATA TYPE Like , LIST in a SET
# > #### Then IT Will Throw ERROR

# %%
st = { [ 12, 34, 56] , 34, 'Messi'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[187], line 1
# ----> 1 st = { [ 12, 34, 56] , 34, 'Messi'}
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# > #### But, IF We Use , IMMUTABLE Data Type Like , TUPLE ,
# > #### SET will Be CREATED

# %%
st = { ( 12, 34, 56) , 34, 'Messi'}

print(st)
# Out:
# {34, 'Messi', (12, 34, 56)}

# %% [markdown]
# ### SETS Have NO INDEXING

# %% [markdown]
# ### HASHING is Important Feature in Case of SET

# %% [markdown]
# ## CAN NOT CREATE 2D SET or 3D SET
# > #### As 2D , 3D SET will contain SETS WITHIN SET,
# > #### And SETS are MUTABLE Data Type
# > #### SO , SET CAN NOT Contain MUTABLE Data ( SET Itself ) Within IT

# %% [markdown]
# ## ACCESSING SET
# > #### INDEXING Not Allowed , so Can Not ACCESS Using INDEX

# %%
st [-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[192], line 1
# ----> 1 st [-1]
#
# TypeError: 'set' object is not subscriptable

# %%
st [2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[193], line 1
# ----> 1 st [2]
#
# TypeError: 'set' object is not subscriptable

# %%
id(st)
# Out:
# 2526425749696

# %% [markdown]
# ## We CAN MODIFY SET Indirectly , Through TYPE CONVERSION ,
# > #### Like , Converting SET to LIST ,
# > #### Modifying LIST ,
# > #### then Again Converting to SET

# %%
ls = list (st)
print(ls)
# Out:
# [34, 'Messi', (12, 34, 56)]

# %%
ls[1] = 'Leonel'

# %%
ls [0] = 39

# %%
print(ls)
# Out:
# [39, 'Leonel', (12, 34, 56)]

# %%
st = set(ls)

# %%
print(st)
# Out:
# {'Leonel', (12, 34, 56), 39}

# %%
type(st)
# Out:
# set

# %%
id(st) ## Memory Location Also Changed
# Out:
# 2526425751936

# %% [markdown]
# ### ADDING ELEMENT Into SET

# %%
st.add('Puyol')

# %% [markdown]
# > ### Value Got ADDED to SET , Hence , SET is MUTABLE

# %%
print(st)
# Out:
# {'Puyol', 'Leonel', (12, 34, 56), 39}

# %% [markdown]
# ### REMOVING ELEMENT from SET Using  remove ( ) , pop ( )

# %%
st.remove('Leonel')

# %%
print(st)
# Out:
# {'Puyol', (12, 34, 56), 39}

# %%
st.pop()
# Out:
# 'Puyol'

# %%
st.pop()
# Out:
# (12, 34, 56)

# %%
print(st)
# Out:
# {39}

# %% [markdown]
# ### ARITHMATIC OPERATORS Do NOT WORK on SET

# %%
st_1 = { 12, 34, 45}
st_2 = { 67, 79, 80}

st_1 + st_2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[216], line 4
#       1 st_1 = { 12, 34, 45}
#       2 st_2 = { 67, 79, 80}
# ----> 4 st_1 + st_2
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
st_1 * 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[217], line 1
# ----> 1 st_1 * 2
#
# TypeError: unsupported operand type(s) for *: 'set' and 'int'

# %% [markdown]
# ## LOOPING on SETS

# %%
for i in st_1:
    print(i)
# Out:
# 34
# 12
# 45

# %% [markdown]
# ### MEMBERSHIP OPERATOR

# %%
21 in st_1
# Out:
# False

# %%
34 in st_1
# Out:
# True

# %% [markdown]
# ## FUNCTIONS on SETS --> len ( ) , min ( ) , max ( ) , sum ( )

# %%
len ( st_1)
# Out:
# 3

# %%
min ( st_1)
# Out:
# 12

# %%
max (st_1)
# Out:
# 45

# %%
sum (st_1)
# Out:
# 91

# %% [markdown]
# ### SORTING SET with SORTED ( )

# %%
sorted(st_1)
# Out:
# [12, 34, 45]

# %%
sorted ( st_1 , reverse = True)
# Out:
# [45, 34, 12]

# %% [markdown]
# * ### UNION ( ) – Combines all unique elements from two or more sets into a single set.
# * ### INTERSECTION ( ) – Returns only the elements that are common to all the sets.
# * ### DIFFERENCE ( ) – Returns the elements that are present in the first set but not in the second set.
# * ### SYMMETRIC DIFFERENCE ( )  – Returns the elements that are present in either set, but not in both.
# * ### ISDISJOINT ( ) – Checks whether two sets have no common elements and returns `True` if they are completely different.
# * ### ISSUBSET ( ) – Checks whether all elements of one set are contained in another set.
# * ### ISSUPERSET ( ) – Checks whether one set contains all the elements of another set.

# %%
st_1 = { 12, 23, 34, 45, 56, 67}

st_2 = { 45 , 67 , 78, 89, 90}

# %%
st_1.union(st_2)
# Out:
# {12, 23, 34, 45, 56, 67, 78, 89, 90}

# %%
st_1.intersection(st_2)
# Out:
# {45, 67}

# %%
st_1.difference(st_2)
# Out:
# {12, 23, 34, 56}

# %%
st_1.symmetric_difference(st_2)
# Out:
# {12, 23, 34, 56, 78, 89, 90}

# %%
st_1 .isdisjoint(st_2)
# Out:
# False

# %%
st_1.issubset(st_2)
# Out:
# False

# %%
st_1.issuperset(st_2)
# Out:
# False

# %% [markdown]
# ## DICTIONARY

# %% [markdown]
# > #### DICTIONARIES Have KEY - VALUE Pair

# %% [markdown]
# ### RULES:
# > #### DICTIONARY Has NO INDEXING
# > #### DICTIONARY is a MUTABLE Data Type
# > #### KEYS should be IMMUTABLE
# > #### VALUES Can Be MUTABLE or IMMUTABLE
# > #### KEYS Should be UNIQUE

# %% [markdown]
# > ## MUTABLE & IMMUTABLE Data Types:
# >> ### MUTABLE --> LIST , SET , DICTIONARY
# >> ### IMMUTABLE --> STRINGS , TUPLE , INT , FLOAT , BOOLEAN , COMPLEX etc

# %% [markdown]
# ### CREATING a DICTIONARY

# %%
dc = {} # Empty Dictionary

dc1 = { 'name' : 'Leonel' , 'age' : 39 , 'gender' : 'Male' , 'active' : True}
dc2 = { 'name' : 'Thierry' , 'age' : 42 , 'gender' : 'Male' , 'active' : False}

# %%
print(dc1)
# Out:
# {'name': 'Leonel', 'age': 39, 'gender': 'Male', 'active': True}

# %%
print(dc2)
# Out:
# {'name': 'Thierry', 'age': 42, 'gender': 'Male', 'active': False}

# %% [markdown]
# ### KEYS should be IMMUTABLE
# > #### As LIST is MUTABLE , SO , Can NOT Take LIST as KEY , It will Throw ERROR
# > #### But , If we Take TUPLE as KEY , It Will WORK FINE , as TUPLE is IMMUTABLE

# %%
dc = { [ 1, 23, 43] : 'Leonel'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[258], line 1
# ----> 1 dc = { [ 1, 23, 43] : 'Leonel'}
#
# TypeError: unhashable type: 'list'

# %%
dc = { ( 1, 23, 43) : 'Leonel'}

# %%
print(dc)
# Out:
# {(1, 23, 43): 'Leonel'}

# %% [markdown]
# ### KEYS Should Be UNIQUE
# > #### If We Take Two KYES of SAME Name and Then Assign Different Values ,
# > #### It will Just UPDATE the Value , It Will Not Consider BOTH to be Different KEYS

# %%
dc = { 'name' : 'Messi' , 'name' : 'Henry'}

# %%
print(dc)
# Out:
# {'name': 'Henry'}

# %% [markdown]
# ### CREATING 2D DICTIONARY

# %%
dc2 = { 'name' : 'Leo' , 'age' : 39 , 'profession' : { 'name' : ' Henry' , 'age' : 48 }}

# %%
print(dc2)
# Out:
# {'name': 'Leo', 'age': 39, 'profession': {'name': ' Henry', 'age': 48}}

# %% [markdown]
# ### CREATING 3D DICTIONARY

# %%
dc3 = { 'name' : 'Leo' , 'age' : 39 ,
        "profession" : { 'name' : ' Henry' , 'age' : 48  ,
                         "profession" : { 'name' : 'Villa' , 'age' : 49 ,"profession" : 'Football'   }} }

# %%
print(dc3)
# Out:
# {'name': 'Leo', 'age': 39, 'profession': {'name': ' Henry', 'age': 48, 'profession': {'name': 'Villa', 'age': 49, 'profession': 'Football'}}}

# %% [markdown]
# ### ACCSESSING DICTIONARY
# > #### We Have To Mention KEY to ACCESS a DICTIONARY
# > #### Can NOT ACCESS with INDEX

# %%
dc1
# Out:
# {'name': 'Leonel', 'age': 39, 'gender': 'Male', 'active': True}

# %%
dc1[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[274], line 1
# ----> 1 dc1[1]
#
# KeyError: 1

# %%
dc1['age']
# Out:
# 39

# %%
dc2['name']
# Out:
# 'Leo'

# %%
dc3['profession']
# Out:
# {'name': ' Henry',
#  'age': 48,
#  'profession': {'name': 'Villa', 'age': 49, 'profession': 'Football'}}

# %%
dc3['profession']['profession']
# Out:
# {'name': 'Villa', 'age': 49, 'profession': 'Football'}

# %%
dc3['profession']['profession']['name']
# Out:
# 'Villa'

# %%
dc3['profession']['profession']['age']
# Out:
# 49

# %% [markdown]
# ### MODIFYING VALUE in DICTIONARY

# %%
dc1
# Out:
# {'name': 'Leonel', 'age': 39, 'gender': 'Male', 'active': True}

# %%
dc1['age'] = 40

# %%
print(dc1)
# Out:
# {'name': 'Leonel', 'age': 40, 'gender': 'Male', 'active': True}

# %% [markdown]
# #### In 2D DICTIONARY

# %%
dc2
# Out:
# {'name': 'Leo', 'age': 39, 'profession': {'name': ' Henry', 'age': 48}}

# %%
dc2 ['profession'] [ 'name'] = 'Maradona'

# %%
print(dc2)
# Out:
# {'name': 'Leo', 'age': 39, 'profession': {'name': 'Maradona', 'age': 48}}

# %% [markdown]
# #### In 3D DICTIONARY

# %%
dc3
# Out:
# {'name': 'Leo',
#  'age': 39,
#  'profession': {'name': ' Henry',
#   'age': 48,
#   'profession': {'name': 'Villa', 'age': 49, 'profession': 'Football'}}}

# %%
dc3 ['profession']['profession'] ['name'] = 'Ronaldo'

# %%
print(dc3)
# Out:
# {'name': 'Leo', 'age': 39, 'profession': {'name': ' Henry', 'age': 48, 'profession': {'name': 'Ronaldo', 'age': 49, 'profession': 'Football'}}}

# %% [markdown]
# ### get ( )
# > ### For 1D DICTIOANARY  , We can Use get ( ) Function to Display Value for a Specific Key ,
# > ### But, get ( ) does not Work for 2D and 3D

# %%
dc1 .get('name')
# Out:
# 'Leonel'

# %% [markdown]
# ### ADDING a NEW KEY - VALUE PAIR

# %%
dc1 [ 'country'] = 'Argentina'

# %%
dc1
# Out:
# {'name': 'Leonel',
#  'age': 40,
#  'gender': 'Male',
#  'active': True,
#  'country': 'Argentina'}

# %%
dc2
# Out:
# {'name': 'Leo', 'age': 39, 'profession': {'name': 'Maradona', 'age': 48}}

# %%
dc2 [ 'profession'] [ 'country ' ] = ' Argentina'

# %%
dc2
# Out:
# {'name': 'Leo',
#  'age': 39,
#  'profession': {'name': 'Maradona', 'age': 48, 'country ': ' Argentina'}}

# %%
dc3
# Out:
# {'name': 'Leo',
#  'age': 39,
#  'profession': {'name': ' Henry',
#   'age': 48,
#   'profession': {'name': 'Ronaldo', 'age': 49, 'profession': 'Football'}}}

# %%
dc3 [ 'profession'][ 'profession'] ['country'] = ' Argentina'

# %%
dc3
# Out:
# {'name': 'Leo',
#  'age': 39,
#  'profession': {'name': ' Henry',
#   'age': 48,
#   'profession': {'name': 'Ronaldo',
#    'age': 49,
#    'profession': 'Football',
#    'country': ' Argentina'}}}

# %% [markdown]
# ## DELETION in DICTIONARY

# %%
del dc3

# %%
dc3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[308], line 1
# ----> 1 dc3
#
# NameError: name 'dc3' is not defined

# %%
del dc1 ['age']

# %%
dc1
# Out:
# {'name': 'Leonel', 'gender': 'Male', 'active': True, 'country': 'Argentina'}

# %%
del dc1 [ 'gender' ]

# %%
dc1
# Out:
# {'name': 'Leonel', 'active': True, 'country': 'Argentina'}

# %%
del dc1 [ 'active']

# %%
dc1
# Out:
# {'name': 'Leonel', 'country': 'Argentina'}

# %% [markdown]
# ### CLEARING or MAKING DICTIONARY EMPTY Using Clear ( )

# %%
dc1.clear( )

# %%
dc1
# Out:
# {}

# %% [markdown]
# ### OPERATORS on DICTIONARY
# > #### Arithmatic Operators Don't Work on Dictionary

# %%
dc1 + dc2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[319], line 1
# ----> 1 dc1 + dc2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
dc2 * 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[320], line 1
# ----> 1 dc2 * 3
#
# TypeError: unsupported operand type(s) for *: 'dict' and 'int'

# %%
dc2
# Out:
# {'name': 'Leo',
#  'age': 39,
#  'profession': {'name': 'Maradona', 'age': 48, 'country ': ' Argentina'}}

# %% [markdown]
# ## LOOPING on DICTIONARY
# > ### If we Directly Run Loop and Print , It will Show KEYs
# > ### To Get KEY - VALUE Pair , We Need to Use , ( i , dc1[i]) Format

# %%
for i in dc2:
    print(i)
# Out:
# name
# age
# profession

# %%
for i in dc2 :
    print(i , dc2[i])
# Out:
# name Leo
# age 39
# profession {'name': 'Maradona', 'age': 48, 'country ': ' Argentina'}

# %%
'name' in dc2
# Out:
# True

# %%
'country' in dc2
# Out:
# False

# %% [markdown]
# ## FUNCTIONS on DICTIONARY
# > ### len ( ) , min ( ) , max ( )
# > ### sorted ( )
# > ### keys ( )
# > ### values ( )

# %%
len ( dc2)
# Out:
# 3

# %%
min ( dc2)
# Out:
# 'age'

# %%
max ( dc2 )
# Out:
# 'profession'

# %%
sorted ( dc2)
# Out:
# ['age', 'name', 'profession']

# %%
sorted ( dc2 , reverse = True)
# Out:
# ['profession', 'name', 'age']

# %%
dc2
# Out:
# {'name': 'Leo',
#  'age': 39,
#  'profession': {'name': 'Maradona', 'age': 48, 'country ': ' Argentina'}}

# %%
dc2. keys()
# Out:
# dict_keys(['name', 'age', 'profession'])

# %%
dc2. values()
# Out:
# dict_values(['Leo', 39, {'name': 'Maradona', 'age': 48, 'country ': ' Argentina'}])
